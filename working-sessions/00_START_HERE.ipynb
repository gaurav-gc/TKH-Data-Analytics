# %% [markdown]
# # Welcome to TKH Data Science!
#
# Run each cell below to confirm everything is set up correctly.

# %% [markdown]
# ## Cell 1 — Check Python version

# %%
import sys
print(f"Python version: {sys.version}")
assert sys.version_info >= (3, 12), "Python 3.12+ required"
print("✓ Python version correct!")

# %% [markdown]
# ## Cell 2 — Check core packages

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import ipywidgets as widgets
import sklearn
import statsmodels
print("✓ Core packages installed!")
print(f"  numpy: {np.__version__}")
print(f"  pandas: {pd.__version__}")
print(f"  sklearn: {sklearn.__version__}")

# %% [markdown]
# ## Cell 3 — Check tkh_utils

# %%
from tkh_utils import (
    PALETTE, FONT, base_layout,
    check_answer, make_answer_key,
    make_grading_summary
)
print("✓ tkh_utils working!")

# %% [markdown]
# ## Cell 4 — Check widgets

# %% [markdown]
# > **Note:** When you run a cell with an interactive widget for the first time, VS Code will show a popup saying *"Widgets require us to download supporting files from a 3rd party website."* — click **Ok**. This is expected and only happens once per session.

# %%
import plotly.graph_objects as go
fig = go.FigureWidget(
    data=[go.Bar(x=['A', 'B'], y=[1, 2])]
)
display(fig)
print("✓ Interactive widgets working!")

# %% [markdown]
# ## Cell 5 — You're ready!

# %%
print("=" * 40)
print("Your environment is ready!")
print("=" * 40)
print()
print("For Week 1, open:")
print("  working-sessions/python/")
print()
print("Start with:")
print("  01_data_types_variables_operators.ipynb")
